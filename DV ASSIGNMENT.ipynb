# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Medicaldataset.csv")
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      63       1          66                      160
# 1      20       1          94                       98
# 2      56       1          64                      160
# 3      66       1          70                      120
# 4      54       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
df.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   63       1          66                      160                        83
# 1   20       1          94                       98                        46
# 2   56       1          64                      160                        77
# 3   66       1          70                      120                        55
# 4   54       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Age", y="Result", data=df, palette="viridis")
# Out:
# <Axes: xlabel='Age', ylabel='Result'>

# %%
# Plot 1: Histogram of Age
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', kde=True, color='skyblue')
plt.title('Distribution of Patient Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Plot 2: Countplot of Gender
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', data=df, palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Plot 3: Scatterplot of Heart rate vs. Systolic blood pressure
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Heart rate', y='Systolic blood pressure', data=df, hue='Result', palette='Set2')
plt.title('Scatterplot of Heart rate vs. Systolic blood pressure')
plt.xlabel('Heart rate')
plt.ylabel('Systolic blood pressure')
plt.tight_layout()
plt.show()

# %%
# Plot 4: Boxplot of Blood sugar by Result
plt.figure(figsize=(10, 6))
sns.boxplot(x='Result', y='Blood sugar', data=df, palette='muted')
plt.title('Blood sugar distribution by Result')
plt.xlabel('Result')
plt.ylabel('Blood sugar')
plt.tight_layout()
plt.show()

# %%
# Plot 5: Violinplot of Troponin by Result
plt.figure(figsize=(10, 6))
sns.violinplot(x='Result', y='Troponin', data=df, palette='viridis')
plt.title('Troponin distribution by Result')
plt.xlabel('Result')
plt.ylabel('Troponin')
plt.tight_layout()
plt.show()
